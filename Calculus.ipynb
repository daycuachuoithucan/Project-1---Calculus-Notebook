# %%
import matplotlib.pyplot as plt
import math
import numpy as np
import statsmodels.api as sm

# %% [markdown]
# # 1. Preparation for Calculus

# %% [markdown]
# ## 1.1. Graph and Models

# %% [markdown]
# Concept check:
#
# 1. Describe how to find the x- and y-intercepts of the graph of an equation
#
# Solution: thay thế lần lượt x và y == 0 để tìm giá trị tương ứng của y và x. Đây chính là x- và y-intercepts của graph
#
# ________________________________________________________________________________
#
# 2. Verifying Points of Intersection: How can you check that an ordered pair is a point of intersection of two graphs?
#
# Solution: thay thế lần lượt x và y vào 2 phương trình, nếu kết quả đều đúng thì có nghĩa là that ordered pair là a point of intersection of 2 graphs
#
# ________________________________________________________________________________
#
# 3. b
# 4. d
# 5. a
# 6. c

# %%
# 7.

x_7 = list(range(-100, 100))
y_7 = []

for x in x_7:
  y = 1/2*x + 2
  y_7.append(y)

plt.plot(x_7, y_7)

# %%
# 8.

x_8 = list(range(-100, 100))
y_8 = []

for x in x_8:
  y = 5 - 2*x
  y_8.append(y)

plt.plot(x_8, y_8)

# %%
# 9.

x_9 = list(range(-100, 100))
y_9 = []
for x in x_9:
  y = 4 - x**2
  y_9.append(y)

plt.plot(x_9, y_9)

# %%
# 10.

x_10 = list(range(-100, 100))
y_10 = []

for x in x_10:
  y = (x-3)**2
  y_10.append(y)

plt.plot(x_10, y_10)

# %%
# 11.

x_11 = list(range(-100, 100))
y_11 = []

for x in x_11:
  y = abs(x + 1)
  y_11.append(y)

plt.plot(x_11, y_11)

# %%
# 12.

x_12 = list(range(-10, 10))
y_12 = []

for x in x_12:
  y = abs(x) - 1
  y_12.append(y)

plt.plot(x_12, y_12)

# %%
# 13.

x_13 = list(range(0, 1000))
y_13 = []

for x in x_13:
  y = math.sqrt(x) - 6
  y_13.append(y)

plt.plot(x_13, y_13)

# %%
# 14.

x_14 = list(range(-2, 100))
y_14 = []

for x in x_14:
  y = math.sqrt(x+2)
  y_14.append(y)

plt.plot(x_14, y_14)

# %%
# 15.

x_15 = list(range(-100, 100))
x_15.remove(0)
y_15 = []

for x in x_15:
  y = 3 / x
  y_15.append(y)

plt.plot(x_15, y_15)

# %%
# 16.

x_16 = list(range(-100, 100))
x_16.remove(-2)
y_16 = []

for x in x_16:
  y = 1 / (x + 2)
  y_16.append(y)

plt.plot(x_16, y_16)

# %%
# 17.

x_17 = list(range(-100, 5))
y_17 = []
for x in x_17:
  y = math.sqrt(5 - x)
  y_17.append(y)

plt.plot(x_17, y_17)

# %%
# 17.

x_17 = 2
y_17 = []
y_17 = math.sqrt(5 - x_17)
print(x_17, y_17)
# Out:
# 2 1.7320508075688772

# %%
# 17.

x_17_new = []
y_17_new = []

y_17 = 3
x_17 = 5 - y_17**2

if x_17 <= 5:
  x_17_new.append(x_17)
  y_17_new.append(y_17)


print(x_17_new, y_17_new)
# Out:
# [-4] [3]

# %%
# 18.

x_18 = list(range(-1000, 1000))
y_18 = []

for x in x_18:
  y = x**5 - 5*x
  y_18.append(y)

plt.plot(x_18, y_18)

# %%
# 19

a_19 = 2
b_19 = -5

y_19 = (0, b_19)
x_19 = (-b_19/a_19, 0)

print(x_19)
print(y_19)
# Out:
# (2.5, 0)
# (0, -5)

# %%
# 20

a_20 = 4
b_20 = 0
c_20 = 3

y_20 = (0, c_20)

delta_20 = b_20**2 - 4*a_20*c_20
if delta_20 > 0:
  x_20_1 = ((-b_20 + math.sqrt(delta_20)) / (2*a_20), 0)
  x_20_2 = ((-b_20 - math.sqrt(delta_20)) / (2*a_20), 0)
  print("x-intercept:", x_20_1, ", y-intercept:", y_20)
  print("x-intercept:", x_20_2, ", y-intercept:", y_20)
elif delta_20 == 0:
  x_20 = (-b_20 / (2*a_20), 0)
  print("x-intercept:", x_20, ", y-intercept:", y_20)
else:
  print ("phương trình không giao với trục Ox", ", y-intercept:", y_20)
# Out:
# phương trình không giao với trục Ox , y-intercept: (0, 3)

# %%
# 21

a_21 = 1
b_21 = 1
c_21 = -2

y_21 = (0, c_21)

delta_21 = b_21**2 - 4*a_21*c_21

if delta_21 > 0:
  x_21_1 = ((-b_21 + math.sqrt(delta_21)) / (2*a_21), 0)
  x_21_2 = ((-b_21 - math.sqrt(delta_21)) / (2*a_21), 0)
  print ("x-intercept:", x_21_1, ", y-intercept:", y_21)
  print ("x-intercept:", x_21_2, ", y-intercept:", y_21)
elif delta_21 == 0:
  x_21 = ((-b_21/(2*a_21)), 0)
  print("x-intercept:", x_21, ", y-intercept:", y_21)
else:
  print("phương trình không giao với trục Ox," , ", y-intercept:", y_21)
# Out:
# x-intercept: (1.0, 0) , y-intercept: (0, -2)
# x-intercept: (-2.0, 0) , y-intercept: (0, -2)

# %%
def finding_intercept_equation_second_degree(a, b, c):

  y_intercept = (0, c)

  delta = b**2 - 4*a*c

  if delta > 0:
    x_intercept_1 = ((-b + math.sqrt(delta)) / (2*a), 0)
    x_intercept_2 = ((-b - math.sqrt(delta)) / (2*a), 0)
    print ("x-intercept:", x_intercept_1, ", y-intercept:", y_intercept)
    print ("x-intercept:", x_intercept_2, ", y-intercept:", y_intercept)
    return y_intercept, x_intercept_1, x_intercept_2

  elif delta == 0:
    x_intercept = ((-b / (2*a)), 0)
    print ("x-intercept:", x_intercept, ", y-intercept:", y_intercept)
    return y_intercept, x_intercept

  else:
    print("phương trình không giao với đường Ox,", "y-intercept:", y_intercept)
    return y_intercept

# %%
# 20
print("câu 20")
finding_intercept_equation_second_degree(4, 0, 3)

print("-----------------------------------------------")
# 21.

print("câu 21")
finding_intercept_equation_second_degree(1, 1, -2)
# Out:
# câu 20
# phương trình không giao với đường Ox, y-intercept: (0, 3)
# -----------------------------------------------
# câu 21
# x-intercept: (1.0, 0) , y-intercept: (0, -2)
# x-intercept: (-2.0, 0) , y-intercept: (0, -2)
# ((0, -2), (1.0, 0), (-2.0, 0))

# %%
# 22.

## - plot ra hết đã
x_22 = list(range(-100, 100))
x_22_used = []
for x in x_22:

  x_cond = x**3 - 4*x

  if x_cond >= 0:
    x_22_used.append(x)

y_22 = []

for x in x_22_used:
  y = math.sqrt(x**3 - 4*x)
  y_22.append(y)

plt.plot(x_22_used, y_22)
plt.axhline(0)
plt.axvline(0)

# %%
# 22.
# nếu x = 0 --> y = 0
print("x-intercept:", (0, 0))

# nếu y = 0 --> y**2 = 0 --> x = 0, -2, 2
print("y-intercept:", (0, 0), (-2, 0), (2, 0))
# Out:
# x-intercept: (0, 0)
# y-intercept: (0, 0) (-2, 0) (2, 0)

# %%
# 23.

print("điều kiện: x thuộc [-4, 4]")

# nếu x = 0 --> y = 0
print("x-intercept:", (0, 0))

# nếu y = 0 --> y**2 = 0 --> x = 0, -4, 4
print("y-intercept:", (0, 0), (-4, 0), (4, 0))
# Out:
# điều kiện: x thuộc [-4, 4]
# x-intercept: (0, 0)
# y-intercept: (0, 0) (-4, 0) (4, 0)

# %%
# 24.

# nếu x = 0 --> y = 1 hoặc -1
print("x-intercept:", (0, 1), (0, -1))

# nếu y = 0 --> x = 1
print("y-intercept:", (1, 0))
# Out:
# x-intercept: (0, 1) (0, -1)
# y-intercept: (1, 0)

# %%
# 25.

# nếu x = 0 --> y = 1 hoặc -1
print("x-intercept:", (0, 1), (0, -1))

# nếu y = 0 --> x = 1
print("y-intercept:", (1, 0))
# Out:
# x-intercept: (0, 1) (0, -1)
# y-intercept: (1, 0)

# %%
# 26.

print("điều kiện: x != -1/3")

# nếu x = 0 --> y = 0
print("x-intercept:", (0, 0))

# nếu y = 0 --> x = 0 hoặc x = -3
print("y-intercept:", (0, 0), (-3, 0))
# Out:
# điều kiện: x != -1/3
# x-intercept: (0, 0)
# y-intercept: (0, 0) (-3, 0)

# %%
# 27.

# nếu x = 0 --> y = 0
print("x-intercept:", (0, 0), ", y-intercept:", (0, 0))
# Out:
# x-intercept: (0, 0) , y-intercept: (0, 0)

# %%
# 28.

# nếu x = 0 --> y = 1 hoặc y = -1
print("x-intercept:", (0, 1), (0, -1))

# nếu y = 0 --> x = 0 hoặc x = sqrt(3) +- 2
print("y-intercept:", (0, math.sqrt(3) + 2), (0, math.sqrt(3) - 2))
# Out:
# x-intercept: (0, 1) (0, -1)
# y-intercept: (0, 3.732050807568877) (0, -0.2679491924311228)

# %%
# 29. 

x_29 = list(range(-100, 100))
y_29 = []

for x in x_29:
    y = x**2 - 6 
    y_29.append(y)

plt.plot(x_29, y_29)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 30. 

x_30 = list(range(-100, 100))
y_30 = []

for x in x_30:
    y = 9*x - x**2
    y_30.append(y)

plt.plot(x_30, y_30)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 31.

x_31 = list(range(-100, 100))
x_31_used = []
y_31 = []

for x in x_31:
    y_square = x**3 - 8*x
    if y_square >= 0:
        x_31_used.append(x)

for x in x_31_used:
    y = math.sqrt(x**3 - 8*x)
    y_31.append(y)

plt.plot(x_31_used, y_31)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 32. 

x_32 = list(range(-100, 100))
y_32 = []

for x in x_32:
    y = x**3 + x
    y_32.append(y)

plt.plot(x_32, y_32)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 33. 

x_33 = list(range(-100, 100))
x_33.remove(0)
y_33 = []

for x in x_33:
    y = 4 / x
    y_33.append(y)

plt.plot(x_33, y_33)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 34. 

x_34 = list(range(-100, 0))
y_34 = []

for x in x_34:
    y = math.sqrt(-10 / x)
    y_34.append(y)

plt.plot(x_34, y_34)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 35. 

x_35 = list(range(-3, 100))
y_35 = []

for x in x_35:
    y = 4 - math.sqrt(x + 3)
    y_35.append(y)

plt.plot(x_35, y_35)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 36. 

x_36 = list(range(-2, 2))
x_36.remove(0)
y_36 = []

for x in x_36:
    y = (4 - x**2) / x
    y_36.append(y)

plt.plot(x_36, y_36)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 37. 

x_37 = np.arange(-100, 100, 0.01, dtype=float)
y_37 = []

for x in x_37:
    y = x / (x**2 + 1)
    y_37.append(y)

plt.plot(x_37, y_37)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 38. 

x_38 = list(range(-10, 10))
x_38.remove(2)
x_38.remove(-2)
y_38 = []

for x in x_38:
    y = x**5 / (4 - x**2)
    y_38.append(y)

plt.plot(x_38, y_38)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 39. 

x_39 = np.arange(-10, 10, 0.1, dtype=float)
y_39 = []

for x in x_39:
    y = abs(x**3 + x)
    y_39.append(y)

plt.plot(x_39, y_39)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 40. 

x_40 = list(range(-3, 10))
y_40_1 = []
y_40_2 = []

for x in x_40:
    y_1 = x + 3
    y_2 = -x - 3
    y_40_1.append(y_1)
    y_40_2.append(y_2)

plt.plot(x_40, y_40_1)
plt.plot(x_40, y_40_2)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 41. 

x_41 = list(range(-10, 10))
y_41 = []

for x in x_41:
    y = 2 - 3*x
    y_41.append(y)

plt.plot(x_41, y_41)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 42. 

x_42 = list(range(-10, 10))
y_42 = []

for x in x_42:
    y = (2/3)*x + 1
    y_42.append(y)

plt.plot(x_42, y_42)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 43. 

x_43 = np.arange(-10, 10, 0.1, dtype=float)
y_43 = []

for x in x_43:
    y = 9 - x**2
    y_43.append(y)

plt.plot(x_43, y_43)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 44. 

x_44 = np.arange(-10, 10, 0.01, dtype=float)
y_44 = []

for x in x_44:
    y = 2*x**2 + x
    y_44.append(y)

plt.plot(x_44, y_44)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 45. 

x_45 = list(range(-10, 10))
y_45 = []

for x in x_45:
    y = x**3 + 2
    y_45.append(y)

plt.plot(x_45, y_45)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 46. 

x_46 = list(range(-10, 10))
y_46 = []

for x in x_46:
    y = x**3 - 4*x
    y_46.append(y)

plt.plot(x_46, y_46)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 47. 

x_47 = np.arange(-5, 10, 0.01, dtype=float)
y_47 = []

for x in x_47:
    y = x*(math.sqrt(x+5))
    y_47.append(y)

plt.plot(x_47, y_47)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 48. 

x_48 = np.arange(-5, 5, 0.01, dtype=float)
y_48 = []

for x in x_48:
    y = math.sqrt(25 - x**2)
    y_48.append(y)

plt.plot(x_48, y_48)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 49. 

x_49 = np.arange(-10, 10, 0.01, dtype=float)
y_49 = []

for x in x_49:
    y = np.cbrt(x)
    y_49.append(y)

plt.plot(x_49, y_49)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 50. 

x_50 = list(range(-16, 100))
y_50 = []

for x in x_50:
    y = (x + 16)**(1/4)
    y_50.append(y)

plt.plot(x_50, y_50)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 51. 

x_51 = np.arange(-1, 1, 0.1, dtype=float)
x_51 = x_51[x_51 != 0]
y_51 = []

for x in x_51:
    y = 8 / x
    y_51.append(y)

plt.plot(x_51, y_51)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 52. 

x_52 = np.arange(-4, 4, 0.01, dtype=float)
y_52 = []

for x in x_52:
    y = 10 / (x**2 + 1)
    y_52.append(y)

plt.plot(x_52, y_52)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 53. 

x_53 = np.arange(-10, 10, 0.01, dtype=float)
y_53 = []

for x in x_53:
    y = 6 - abs(x)
    y_53.append(y)

plt.plot(x_53, y_53)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 54. 

x_54 = np.arange(-10, 10, 0.01, dtype=float)
y_54 = []

for x in x_54:
    y = abs(6 - x)
    y_54.append(y)

plt.plot(x_54, y_54)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 56. 

x_56 = np.arange(-2, 2, 0.001, dtype=float)
y_56 = []

for x in x_56:
    y = math.sqrt((4 - x**2) / 4)
    y_56.append(y)

plt.plot(x_56, y_56)
plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 57.

print("x = 3, y = 5")
# Out:
# x = 3, y = 5

# %%
# 58.

print("x = 3, y = 5")
# Out:
# x = 3, y = 5

# %%
# 59.

print("x = 1, y = 14")
print("x = -1, y = -4")
# Out:
# x = 1, y = 14
# x = -1, y = -4

# %%
# 60.

print("x = 2, y = 1")
print("x = -1, y = -2")
# Out:
# x = 2, y = 1
# x = -1, y = -2

# %%
# 61.

print("x = 2, y = 1")
print("x = -1, y = -2")
# Out:
# x = 2, y = 1
# x = -1, y = -2

# %%
# 62.

print("x = 4, y = 0")
print("x = 16/5, y = -12/5")
# Out:
# x = 4, y = 0
# x = 16/5, y = -12/5

# %%
# 63.

y_63_1 = []
y_63_2 = []

x_63 = np.arange(-3, 3, 0.1, dtype=float)

y_63_1 = x_63**3 - 2*x_63**2 + x_63 - 1
y_63_2 = -x_63**2 + 3*x_63 - 1

plt.figure(figsize=(8,8))
plt.plot(x_63, y_63_1, color = 'black')
plt.plot(x_63, y_63_2, color = 'blue')
plt.axhline(0)
plt.axvline(0)
plt.grid(True)
print("x=0, x=2, x=-1")
# Out:
# x=0, x=2, x=-1

# %%
# 64.

x_64 = np.arange(-1.5, 1.5, 0.01, dtype=float)

y_64_1 = x_64**4 - 2*(x_64**2) + 1
y_64_2 = 1 - x_64**2

plt.figure(figsize=(8,8))
plt.plot(x_64, y_64_1, color = "black")
plt.plot(x_64, y_64_2, color = "blue")
plt.axhline(0)
plt.axvline(0)
plt.grid(True)
print("x = -1, 0, 1")
# Out:
# x = -1, 0, 1

# %%
# 65.

x_65 = np.arange(-4, 0, 0.01, dtype=float)

y_65_1 = np.sqrt(x_65 + 6)
y_65_2 = np.sqrt(-x_65**2 - 4*x_65)

plt.figure(figsize=(8,8))
plt.plot(x_65, y_65_1, color = "black")
plt.plot(x_65, y_65_2, color = "blue")
plt.grid(True)
print()

# %%
# 66.

x_66 = np.arange(-4, 4, 0.01, dtype=float)

y_66_1 = -abs(2*x_66 - 3) + 6
y_66_2 = 6 - x_66

plt.figure(figsize=(8,8))
plt.plot(x_66, y_66_1, color = "black")
plt.plot(x_66, y_66_2, color = "blue")
plt.axhline(0)
plt.axvline(0)
plt.grid(True)
print()

# %%
# 67.a.

y_67 = [14.4, 15, 15.5, 16.2, 16.7, 17.3]
x_67 = np.arange(9, 15)

X_67 = sm.add_constant(x_67)

model_67 = sm.OLS(y_67, X_67)
ols_67 = model_67.fit()

print(ols_67.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                     2943.
# Date:                Thu, 07 May 2026   Prob (F-statistic):           6.91e-07
# Time:                        12:22:46   Log-Likelihood:                 11.347
# No. Observations:                   6   AIC:                            -18.69
# Df Residuals:                       4   BIC:                            -19.11
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.1800      0.124     73.860      0.000       8.835       9.525
# ...

# %%
# 67.b.

constant_67 = ols_67.params[0]
slope_67 = ols_67.params[1]
y_hat_67 = slope_67*x_67 + constant_67

plt.figure(figsize=(12,12))
plt.plot(x_67, y_67, color = "black")
plt.plot(x_67, y_hat_67, color = "blue")
plt.grid(True)

# %%
# 67.c.

x_predict_67 = 24.0

y_predict_67 = constant_67 + slope_67*x_predict_67
print(f"GDP in the year 2024 is {y_predict_67: .2f}")
# Out:
# GDP in the year 2024 is  23.10

# %%
# 67.a.

y_67 = [14.4, 15, 15.5, 16.2, 16.7, 17.3]
x_67 = np.arange(9, 15)

X_67 = sm.add_constant(x_67)

model_67 = sm.OLS(y_67, X_67)
ols_67 = model_67.fit()

print(ols_67.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                     2943.
# Date:                Thu, 07 May 2026   Prob (F-statistic):           6.91e-07
# Time:                        12:22:46   Log-Likelihood:                 11.347
# No. Observations:                   6   AIC:                            -18.69
# Df Residuals:                       4   BIC:                            -19.11
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.1800      0.124     73.860      0.000       8.835       9.525
# ...

# %%
# 68.a.

x_68 = np.array([0, 2, 4, 6, 8, 10, 12, 14])
x_68_square = x_68**2
y_68 = [109.0, 141.0, 182.0, 233.0, 270.0, 296.0, 326.0, 355.0]
X_68 = np.column_stack((x_68, x_68_square))
X_68 = sm.add_constant(X_68)

model_68 = sm.OLS(y_68, X_68)
ols_68 = model_68.fit()
print(ols_68.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                     706.4
# Date:                Thu, 07 May 2026   Prob (F-statistic):           7.39e-07
# Time:                        12:22:46   Log-Likelihood:                -24.106
# No. Observations:                   8   AIC:                             54.21
# Df Residuals:                       5   BIC:                             54.45
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        103.1667      5.243     19.677      0.000      89.689     116.644
# ...

# %%
ols_68.params[2]
# Out:
# np.float64(-0.34821428571428914)

# %%
# 68.b.

constant_68 = ols_68.params[0]
slope_1_68 = ols_68.params[1]
slope_2_68 = ols_68.params[2]
y_hat_68 = constant_68 + slope_1_68*x_68 + slope_2_68*x_68_square

plt.figure(figsize=(18,6))
plt.plot(x_68, y_68, color = "black")
plt.plot(x_68, y_hat_68, color = "red")

# plt.plot(x_68_square, y_68, color = "blue")
# plt.plot(x_68_square, y_68, color = "green")

plt.axhline(0)
plt.axvline(0)
plt.grid(True)

# %%
# 68.c.

x_68_predict = 24
x_68_square_predict = x_68_predict**2

y_predict_68 = constant_68 + slope_1_68*x_68_predict + slope_2_68*x_68_square_predict
print(f'GDP in the year 2024 is {y_predict_68: .2f}')
# Out:
# GDP in the year 2024 is  451.88

# %%
# 69. 

print(f'Breakeven point is 4480')
# Out:
# Breakeven point is 4480

# %%
# 70.a.
print('for question a, the graph passes through the point at k = 0.25')
# 70.b.
print('for question b, the graph passes through the point at k = 2')
# 70.c.
print('for question c, the graph always passes through the point regardless k values')
# 70.d.
print('for question d, the graph pass through the point at k = 0.75')
# Out:
# for question a, the graph passes through the point at k = 0.25
# for question b, the graph passes through the point at k = 2
# for question c, the graph always passes through the point regardless k values
# for question d, the graph pass through the point at k = 0.75

# %% [markdown]
# 71. Intercept
#
# Là intersection giữa graph và Ox tại điểm Oy = 0 --> phương trình tìm nghiệm x khi y = 0
#
# 72. Symmetry
#
# Khi 1 graph đã symmetric qua cả Ox và Oy thì graph đó sẽ symmetric qua origin, vì origin là điểm giao giữa Ox và Oy
#
# 73. Symmetry
#
# Vì origin là intersection của Ox và Oy, nên khi 1 graph đã symmetric qua 1 trong 2 line và origin thì nó cũng sẽ symmetric với line còn lại

# %% [markdown]
# 74.
#
# a.
#
# Eq(1) y = x**2 + 2: không có x-intercept; và có 1 y-intercept là (0, 2)
#
# Eq(1) y = x**3 - x: có 3 x-intercept là (-1, 0), (0, 0) và (1, 0); và có 1 y-intercept là (0, 0)
#
# b.
#
# Eq(1) y = x**2 + 2: assymetry qua Oy
#
# Eq(1) y = x**3 - x: assymetry qua cả Ox, Oy --> assymetry qua origin
#
# c.
#
# x**2 + 2 = x**3 - x
#
# --> nhìn hình ta thấy, solution point = (2, 6)

# %% [markdown]
# 75.
#
# If (−4, −5) is a point on a graph that is symmetric with respect to the x-axis, then (4, −5) is NOT also a point on the graph vì 2 điểm này assymetric qua trục Oy, chứ không phải Ox
#
# 76.
#
# If (−4, −5) is a point on a graph that is symmetric with respect to the y-axis, then (4, −5) is also a point on the graph vì 2 điểm này đối xứng qua trục Oy
#
# 77.
#
# Đúng, vì b**2 - 4*a*c là công thức delta để tìm nghiệm phương trình bậc 2, và theo công thức thì delta > 0 là phương trình có 2 nghiệm, tương ứng với có 2 x-intercept
#
# 78.
#
# Đúng, vì b**2 - 4*a*c là công thức delta để tìm nghiệm phương trình bậc 2, và theo công thức thì delta == 0 là phương trình có 1 nghiệm kép, tương ứng với có duy nhất 1 x-intercept

# %% [markdown]
# ## 1.2. Linear Models and Rates of Changes

# %% [markdown]
# # CONTENT VÔ CỰC
